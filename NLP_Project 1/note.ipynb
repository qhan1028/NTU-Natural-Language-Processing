# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ## Project 1: Fine-Grained Sentiment Analysis on Financial Microblogs

# %%
import os
import os.path as osp
import json
import numpy as np
import pandas as pd
import re
from autocorrect import spell

# %%
datadir = 'data/'
savedir = 'models_6/'
if not osp.exists(savedir): os.mkdir(savedir)

# %%
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, MaxPooling1D, Flatten
from keras.layers import LSTM, GRU, Conv1D
from keras.layers import Input, Dense, Dropout, BatchNormalization, Activation
from keras.layers.merge import Concatenate
from keras.models import Sequential, Model, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Read Data

# %%
with open(datadir + 'training_set.json', 'r') as f:
    training_set = pd.DataFrame(json.load(f))

with open(datadir + 'test_set.json', 'r') as f:
    test_set = pd.DataFrame(json.load(f))
    
with open(datadir + 'NTUSD_Fin_word_v1.0.json', 'r') as f:
    word_dict = pd.DataFrame(json.load(f)).set_index('token')

with open(datadir + 'NTUSD_Fin_hashtag_v1.0.json', 'r') as f:
    hashtag_dict = pd.DataFrame(json.load(f)).set_index('token')

# %% [markdown]
# ## Preprocessing

# %%
train_raw = training_set['tweet'].tolist()
train_Y = np.array(training_set['sentiment'].astype(np.float32).tolist())
train_len = len(train_raw)

# %%
test_raw = test_set['tweet'].tolist()
test_Y = np.array(test_set['sentiment'].astype(np.float32).tolist())
test_len = len(test_raw)

# %% [markdown]
# ** Clean Corpus **

# %%
def clean_corpus(corpus):
    for i, data in enumerate(corpus):
        data = re.sub(r'\$[A-Za-z0-9]*[ ,]?', '', data) # remove $ target
        data = re.sub(r'@[a-zA-Z0-9]*', '', data) # remove @ tag
        data = re.sub(r'http.*[a-zA-Z0-9]?', '', data) # remove url
        data = re.sub(r'&#39;', '\'', data) # fix '
        data = re.sub(r'[0-9.,]*[0-9]+', '', data) # remove numbers
        data = re.sub(r'(~?&[a-z]*;)', '', data) # remove Latex
        data = re.sub(r'["$%&()*+\-/:;<=>@[\]^_`{|}~…—\n\t•]|[.]+\.', ' ', data) # remove characters
        data = re.sub(r'#', ' #', data) # split continuous hashtag
        data = re.sub(r' +', ' ', data) # remove space redundancy
        corpus[i] = data
    return corpus

# %%
def general_sentiment(corpus):
    S = []
    for data in corpus:
        S_data = 0.0
        sentences = re.split('[.,!?]', re.sub(r'#[A-Za-z]*', '', data))
        for sentence in sentences:
            S_sentence, v = 1., 0.
            words = [w for w in re.split(' ', sentence) if w != '']
            for word in words:
                try:
                    s = word_dict.loc[word.lower()]['market_sentiment']
                    S_sentence *= s
                    v += 1
                except:
                    pass
            if v > 0:
                S_data += np.sign(S_sentence) * np.abs(S_sentence) ** (1/v)
        S.append(S_data)
    return np.array(S)

# %%
corpus = clean_corpus(train_raw + test_raw)
senti = general_sentiment(corpus)

train_X = corpus[:train_len]
test_X = corpus[train_len:]
train_S = senti[:train_len]
test_S = senti[train_len:]

# %% [markdown]
# ## Construct Word Embedding

# %% [markdown]
# ** Tokenize words **

# %%
filters = '!"$%&()*+,-./:;<=>?@[\]^_`{|}~'
tokenizer = Tokenizer(filters=filters)
tokenizer.fit_on_texts(corpus)
word_index = tokenizer.word_index

# %%
with open(savedir + 'word_index.json', 'w') as f:
    json.dump(word_index, f)

# %% [markdown]
# ** Text to index sequences **

# %%
train_Xi = tokenizer.texts_to_sequences(train_X)
test_Xi = tokenizer.texts_to_sequences(test_X)

# %% [markdown]
# ** Pad index sequences **

# %%
train_Xi = pad_sequences(train_Xi)
maxlen = train_Xi.shape[1]
test_Xi = pad_sequences(test_Xi, maxlen=maxlen)

# %%
num_words = len(word_index) + 1
emb_dim = 300 + 3
embedding_matrix = np.zeros((num_words, emb_dim))

for (word, index) in word_index.items():
    try:
        if word[0] == '#':
            content = hashtag_dict.loc[word[1:]]    
        else:
            content = word_dict.loc[word]
        
        bear = content['bear_cfidf'] / 100
        bull = content['bull_cfidf'] / 100
        sentiment = content['market_sentiment']
        word_vec = content['word_vec']
        embedding_matrix[index] = np.asarray(word_vec + [bear, bull, sentiment], dtype=np.float32)
    except:
        continue

# %% [markdown]
# ## Construct Models

# %% [markdown]
# ### Loss

# %%
def f1(Y, Yp):
    thresh = 0.0
    Yp = K.cast(K.greater(Yp, thresh), dtype='float32')
    Y = K.cast(K.greater(Y, thresh), dtype='float32')
    tp = K.sum(Y * Yp)
    
    precision = tp / (K.sum(Yp))
    recall = tp / (K.sum(Y))
    result = 2 * ((precision * recall) / (precision + recall))
    return result

# %% [markdown]
# ### 1. GRU

# %%
in_emb = Input(shape=(maxlen,), name='Input-Text')
in_senti = Input(shape=(1,), name='Input-Sentiment')

x = Embedding(num_words,
              emb_dim,
              weights=[embedding_matrix],
              input_length=maxlen,
              trainable=False,
              name='Embedding')(in_emb)
x = GRU(128, activation='relu', dropout=0.2, name='GRU')(x)
x = Dense(64, activation='relu', name='Dense')(x)
x = Dropout(0.2, name='Dropout')(x)
x = Concatenate(name='Concatenate')([x, in_senti])
out = Dense(1, activation='tanh', name='Tanh')(x)

gru = Model(inputs=[in_emb, in_senti], outputs=out)
gru.compile(optimizer='adam', loss='mse', metrics=[f1])
#gru.summary()

# %% [markdown]
# ** Train GRU **

# %%
model_path = savedir + 'GRU.h5'

es = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')
cp = ModelCheckpoint(monitor='val_loss', save_best_only=True, save_weights_only=False,
                     mode='min', filepath=model_path)

history = gru.fit([train_Xi, train_S], train_Y, validation_data=([test_Xi, test_S], test_Y),
                  epochs=30, verbose=1, batch_size=32, callbacks=[es, cp])

hist = history.history
# Out:
# Train on 1396 samples, validate on 634 samples
# Epoch 1/30
# 1396/1396 [==============================] - 11s - loss: 0.1823 - f1: 0.7140 - val_loss: 0.1427 - val_f1: 0.7583
# Epoch 2/30
# 1396/1396 [==============================] - 10s - loss: 0.1293 - f1: 0.7959 - val_loss: 0.1229 - val_f1: 0.8092
# Epoch 3/30
# 1396/1396 [==============================] - 6s - loss: 0.1099 - f1: 0.8142 - val_loss: 0.1060 - val_f1: 0.8237
# Epoch 4/30
# 1396/1396 [==============================] - 6s - loss: 0.0977 - f1: 0.8389 - val_loss: 0.0925 - val_f1: 0.8298
# Epoch 5/30
# 1396/1396 [==============================] - 6s - loss: 0.0879 - f1: 0.8459 - val_loss: 0.0858 - val_f1: 0.8536
# Epoch 6/30
# 1396/1396 [==============================] - 6s - loss: 0.0760 - f1: 0.8650 - val_loss: 0.0833 - val_f1: 0.8630
# Epoch 7/30
# 1396/1396 [==============================] - 6s - loss: 0.0725 - f1: 0.8767 - val_loss: 0.0845 - val_f1: 0.8448
# Epoch 8/30
# 1396/1396 [==============================] - 6s - loss: 0.0680 - f1: 0.8763 - val_loss: 0.0806 - val_f1: 0.8477
# Epoch 9/30
# 1396/1396 [==============================] - 6s - loss: 0.0637 - f1: 0.8857 - val_loss: 0.0810 - val_f1: 0.8369
# Epoch 10/30
# 1396/1396 [==============================] - 6s - loss: 0.0566 - f1: 0.9011 - val_loss: 0.0792 - val_f1: 0.8590
# Epoch 11/30
# 1396/1396 [==============================] - 6s - loss: 0.0548 - f1: 0.9063 - val_loss: 0.0775 - val_f1: 0.8479
# Epoch 12/30
# 1396/1396 [==============================] - 6s - loss: 0.0539 - f1: 0.9041 - val_loss: 0.0793 - val_f1: 0.8476
# Epoch 13/30
# 1396/1396 [==============================] - 6s - loss: 0.0471 - f1: 0.9182 - val_loss: 0.0805 - val_f1: 0.8548
# Epoch 14/30
# 1396/1396 [==============================] - 6s - loss: 0.0467 - f1: 0.9195 - val_loss: 0.0797 - val_f1: 0.8455
# Epoch 15/30
# 1396/1396 [==============================] - 6s - loss: 0.0425 - f1: 0.9222 - val_loss: 0.0806 - val_f1: 0.8508
# Epoch 16/30
# 1396/1396 [==============================] - 6s - loss: 0.0414 - f1: 0.9220 - val_loss: 0.0825 - val_f1: 0.8477
# Epoch 17/30
# 1396/1396 [==============================] - 6s - loss: 0.0415 - f1: 0.9234 - val_loss: 0.0826 - val_f1: 0.8495
# Epoch 00016: early stopping

# %% [markdown]
# ** Save GRU Model **

# %%
best_val_mse = np.min(hist['val_loss'])
print('Best MSE:', best_val_mse)
gru_path = savedir + 'GRU_%.4f.h5' % best_val_mse
if osp.exists(model_path): os.rename(model_path, gru_path)
# Out:
# Best MSE: 0.077510135454

# %% [markdown]
# ### 2. LSTM

# %%
in_emb = Input(shape=(maxlen,), name='Input')
in_senti = Input(shape=(1,), name='Input-Sentiment')

x = Embedding(num_words,
              emb_dim,
              weights=[embedding_matrix],
              input_length=maxlen,
              trainable=False,
              name='Embedding')(in_emb)
x = LSTM(128, activation='relu', dropout=0.2, name='LSTM')(x)
x = Dense(64, activation='relu', name='Dense')(x)
x = Dropout(0.2, name='Dropout')(x)
x = Concatenate(name='Concatenate')([x, in_senti])
out = Dense(1, activation='tanh', name='Tanh')(x)

lstm = Model(inputs=[in_emb, in_senti], outputs=out)
lstm.compile(optimizer='adam', loss='mse', metrics=[f1])
#lstm.summary()

# %% [markdown]
# ** Train LSTM **

# %%
model_path = savedir + 'LSTM.h5'

es = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')
cp = ModelCheckpoint(monitor='val_loss', save_best_only=True, save_weights_only=False,
                     mode='min', filepath=model_path)

history = lstm.fit([train_Xi, train_S], train_Y, validation_data=([test_Xi, test_S], test_Y),
                   epochs=30, verbose=1, batch_size=32, callbacks=[es, cp])

hist = history.history
# Out:
# Train on 1396 samples, validate on 634 samples
# Epoch 1/30
# 1396/1396 [==============================] - 11s - loss: 0.1206 - f1: 0.8029 - val_loss: 0.1070 - val_f1: 0.8045
# Epoch 2/30
# 1396/1396 [==============================] - 9s - loss: 0.1011 - f1: 0.8327 - val_loss: 0.0924 - val_f1: 0.8364
# Epoch 3/30
# 1396/1396 [==============================] - 8s - loss: 0.0931 - f1: 0.8397 - val_loss: 0.0860 - val_f1: 0.8408
# Epoch 4/30
# 1396/1396 [==============================] - 9s - loss: 0.0854 - f1: 0.8602 - val_loss: 0.0820 - val_f1: 0.8558
# Epoch 5/30
# 1396/1396 [==============================] - 10s - loss: 0.0802 - f1: 0.8590 - val_loss: 0.0786 - val_f1: 0.8610
# Epoch 6/30
# 1396/1396 [==============================] - 11s - loss: 0.0737 - f1: 0.8703 - val_loss: 0.0773 - val_f1: 0.8642
# Epoch 7/30
# 1396/1396 [==============================] - 11s - loss: 0.0680 - f1: 0.8746 - val_loss: 0.0749 - val_f1: 0.8702
# Epoch 8/30
# 1396/1396 [==============================] - 10s - loss: 0.0632 - f1: 0.8927 - val_loss: 0.0809 - val_f1: 0.8548
# Epoch 9/30
# 1396/1396 [==============================] - 11s - loss: 0.0592 - f1: 0.8896 - val_loss: 0.0778 - val_f1: 0.8500
# Epoch 10/30
# 1396/1396 [==============================] - 10s - loss: 0.0551 - f1: 0.8997 - val_loss: 0.0759 - val_f1: 0.8677
# Epoch 11/30
# 1396/1396 [==============================] - 11s - loss: 0.0518 - f1: 0.9026 - val_loss: 0.0760 - val_f1: 0.8678
# Epoch 12/30
# 1396/1396 [==============================] - 13s - loss: 0.0474 - f1: 0.9149 - val_loss: 0.0763 - val_f1: 0.8606
# Epoch 13/30
# 1396/1396 [==============================] - 12s - loss: 0.0443 - f1: 0.9237 - val_loss: 0.0727 - val_f1: 0.8670
# Epoch 14/30
# 1396/1396 [==============================] - 13s - loss: 0.0415 - f1: 0.9128 - val_loss: 0.0760 - val_f1: 0.8646
# Epoch 15/30
# 1396/1396 [==============================] - 11s - loss: 0.0425 - f1: 0.9228 - val_loss: 0.0710 - val_f1: 0.8696
# Epoch 16/30
# 1396/1396 [==============================] - 10s - loss: 0.0365 - f1: 0.9340 - val_loss: 0.0732 - val_f1: 0.8710
# Epoch 17/30
# 1396/1396 [==============================] - 10s - loss: 0.0357 - f1: 0.9344 - val_loss: 0.0744 - val_f1: 0.8689
# Epoch 18/30
# 1396/1396 [==============================] - 10s - loss: 0.0339 - f1: 0.9320 - val_loss: 0.0777 - val_f1: 0.8677
# Epoch 19/30
# 1396/1396 [==============================] - 9s - loss: 0.0302 - f1: 0.9434 - val_loss: 0.0750 - val_f1: 0.8687
# Epoch 20/30
# 1396/1396 [==============================] - 10s - loss: 0.0304 - f1: 0.9475 - val_loss: 0.0769 - val_f1: 0.8711
# Epoch 21/30
# 1396/1396 [==============================] - 10s - loss: 0.0297 - f1: 0.9457 - val_loss: 0.0770 - val_f1: 0.8656
# Epoch 00020: early stopping

# %% [markdown]
# ** Save LSTM Model **

# %%
best_val_mse = np.min(hist['val_loss'])
print('Best MSE:', best_val_mse)
lstm_path = savedir + 'LSTM_%.4f.h5' % best_val_mse
if osp.exists(model_path): os.rename(model_path, lstm_path)
# Out:
# Best MSE: 0.0709879824228

# %% [markdown]
# ### 3. Conv1D

# %%
in_emb = Input(shape=(maxlen,), name='Input')
in_senti = Input(shape=(1,), name='Input-Sentiment')

x = Embedding(num_words,
              emb_dim,
              weights=[embedding_matrix],
              input_length=maxlen,
              trainable=False,
              name='Embedding')(in_emb)
x = Conv1D(128, 3, activation='relu', name='Conv1D')(x)
x = Flatten()(x)
x = Dense(64, activation='relu', name='Dense')(x)
x = Dropout(0.2, name='Dropout')(x)
x = Concatenate(name='Concatenate')([x, in_senti])
out = Dense(1, activation='tanh', name='Tanh')(x)

conv = Model(inputs=[in_emb, in_senti], outputs=out)
conv.compile(optimizer='adam', loss='mse', metrics=[f1])
conv.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# Input (InputLayer)               (None, 29)            0
# ____________________________________________________________________________________________________
# Embedding (Embedding)            (None, 29, 303)       1092012     Input[0][0]
# ____________________________________________________________________________________________________
# Conv1D (Conv1D)                  (None, 27, 128)       116480      Embedding[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 3456)          0           Conv1D[0][0]
# ____________________________________________________________________________________________________
# Dense (Dense)                    (None, 64)            221248      flatten_3[0][0]
# ____________________________________________________________________________________________________
# Dropout (Dropout)                (None, 64)            0           Dense[0][0]
# ____________________________________________________________________________________________________
# Input-Sentiment (InputLayer)     (None, 1)             0
# ____________________________________________________________________________________________________
# Concatenate (Concatenate)        (None, 65)            0           Dropout[0][0]
#                                                                    Input-Sentiment[0][0]
# ____________________________________________________________________________________________________
# Tanh (Dense)                     (None, 1)             66          Concatenate[0][0]
# ====================================================================================================
# Total params: 1,429,806
# Trainable params: 337,794
# Non-trainable params: 1,092,012
# ____________________________________________________________________________________________________

# %% [markdown]
# ** Train Conv **

# %%
model_path = savedir + 'CONV.h5'

es = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')
cp = ModelCheckpoint(monitor='val_loss', save_best_only=True, save_weights_only=False,
                     mode='min', filepath=model_path)

history = conv.fit([train_Xi, train_S], train_Y, validation_data=([test_Xi, test_S], test_Y),
                   epochs=30, verbose=1, batch_size=32, callbacks=[es, cp])

hist = history.history
# Out:
# Train on 1396 samples, validate on 634 samples
# Epoch 1/30
# 1396/1396 [==============================] - 2s - loss: 0.1346 - f1: 0.7716 - val_loss: 0.0950 - val_f1: 0.8220
# Epoch 2/30
# 1396/1396 [==============================] - 2s - loss: 0.0803 - f1: 0.8516 - val_loss: 0.0800 - val_f1: 0.8463
# Epoch 3/30
# 1396/1396 [==============================] - 2s - loss: 0.0578 - f1: 0.8949 - val_loss: 0.0783 - val_f1: 0.8530
# Epoch 4/30
# 1396/1396 [==============================] - 2s - loss: 0.0406 - f1: 0.9244 - val_loss: 0.0783 - val_f1: 0.8592
# Epoch 5/30
# 1396/1396 [==============================] - 2s - loss: 0.0311 - f1: 0.9460 - val_loss: 0.0783 - val_f1: 0.8485
# Epoch 6/30
# 1396/1396 [==============================] - 1s - loss: 0.0272 - f1: 0.9514 - val_loss: 0.0787 - val_f1: 0.8581
# Epoch 7/30
# 1396/1396 [==============================] - 2s - loss: 0.0224 - f1: 0.9607 - val_loss: 0.0754 - val_f1: 0.8484
# Epoch 8/30
# 1396/1396 [==============================] - 2s - loss: 0.0221 - f1: 0.9594 - val_loss: 0.0758 - val_f1: 0.8585
# Epoch 9/30
# 1396/1396 [==============================] - 2s - loss: 0.0198 - f1: 0.9611 - val_loss: 0.0762 - val_f1: 0.8502
# Epoch 10/30
# 1396/1396 [==============================] - 2s - loss: 0.0181 - f1: 0.9604 - val_loss: 0.0771 - val_f1: 0.8378
# Epoch 11/30
# 1396/1396 [==============================] - 2s - loss: 0.0184 - f1: 0.9643 - val_loss: 0.0762 - val_f1: 0.8575
# Epoch 12/30
# 1396/1396 [==============================] - 1s - loss: 0.0171 - f1: 0.9635 - val_loss: 0.0760 - val_f1: 0.8554
# Epoch 13/30
# 1396/1396 [==============================] - 2s - loss: 0.0167 - f1: 0.9611 - val_loss: 0.0752 - val_f1: 0.8514
# Epoch 14/30
# 1396/1396 [==============================] - 1s - loss: 0.0163 - f1: 0.9656 - val_loss: 0.0774 - val_f1: 0.8570
# Epoch 15/30
# 1396/1396 [==============================] - 1s - loss: 0.0164 - f1: 0.9624 - val_loss: 0.0736 - val_f1: 0.8487
# Epoch 16/30
# 1396/1396 [==============================] - 1s - loss: 0.0163 - f1: 0.9627 - val_loss: 0.0762 - val_f1: 0.8550
# Epoch 17/30
# 1396/1396 [==============================] - 1s - loss: 0.0157 - f1: 0.9647 - val_loss: 0.0765 - val_f1: 0.8570
# Epoch 18/30
# 1396/1396 [==============================] - 1s - loss: 0.0152 - f1: 0.9672 - val_loss: 0.0777 - val_f1: 0.8618
# Epoch 19/30
# 1396/1396 [==============================] - 1s - loss: 0.0155 - f1: 0.9670 - val_loss: 0.0786 - val_f1: 0.8591
# Epoch 20/30
# 1396/1396 [==============================] - 2s - loss: 0.0154 - f1: 0.9708 - val_loss: 0.0776 - val_f1: 0.8487
# Epoch 21/30
# 1396/1396 [==============================] - 2s - loss: 0.0145 - f1: 0.9697 - val_loss: 0.0776 - val_f1: 0.8648
# Epoch 00020: early stopping

# %% [markdown]
# ** Save Conv Model **

# %%
best_val_mse = np.min(hist['val_loss'])
print('Best MSE:', best_val_mse)
conv_path = savedir + 'CONV_%.4f.h5' % best_val_mse
if osp.exists(model_path): os.rename(model_path, conv_path)
# Out:
# Best MSE: 0.0735768427138

# %% [markdown]
# ## Test

# %%
def compute_mse(Y, Yp):
    return np.mean((Y - Yp) ** 2)

def classify_sentiments(Y, thres):
    res = np.zeros(len(Y))
    res[Y > thres] = 1
    res[Y < thres] = -1
    res[(res != 1) & (res != -1)] = 0
    return res

def compute_acc(Y, Yp, thres, Cgt=None):
    if Cgt is None: Cgt = classify_sentiments(Y, thres)
    Cp = classify_sentiments(Yp, thres)
    
    true = (Cgt == Cp)
    tp, tn = true & (Cgt > 0), true & (Cgt < 0)
    
    acc = np.sum(true) / len(Y)
    
    precision = np.sum(tp) / np.sum(Cp[Cp > 0])
    recall = np.sum(tp) / np.sum(Cgt[Cgt > 0])
    f1 = 2 * (precision * recall) / (precision + recall)
    
    return [acc, f1]

# %% [markdown]
# ** Load Best Model **

# %%
gru = load_model(gru_path, custom_objects={'f1': f1})
test_gru = gru.predict([test_Xi, test_S]).flatten()

lstm = load_model(lstm_path, custom_objects={'f1': f1})
test_lstm= lstm.predict([test_Xi, test_S]).flatten()

conv = load_model(conv_path, custom_objects={'f1': f1})
test_conv = conv.predict([test_Xi, test_S]).flatten()

# %% [markdown]
# ** Bullish / Bearish / Neutral **

# %%
thres = 0.0
Cgt = classify_sentiments(test_Y, thres)

res = []
res.append(['GRU'] + compute_acc(test_Y, test_gru, thres, Cgt))
res.append(['LSTM'] + compute_acc(test_Y, test_lstm, thres, Cgt))
res.append(['CONV'] + compute_acc(test_Y, test_conv, thres, Cgt))

res_df = pd.DataFrame(res, columns=['Model', 'Accuracy', 'F1 score'])
res_df
# Out:
#   Model  Accuracy  F1 score
# 0   GRU  0.804416  0.854742
# 1  LSTM  0.826498  0.875878
# 2  CONV  0.802839  0.856132

# %% [markdown]
# ## Ensemble

# %%
def ensemble(model_paths):
    test_ens = np.zeros(test_len)
    for path in model_paths:
        print('model: %s' % path)
        model = load_model(path, custom_objects={'f1': f1})
        test_ens += model.predict([test_Xi, test_S]).flatten()
    return test_ens / len(model_paths)

# %%
model_list = [gru, lstm, conv]
model_paths = [gru_path, lstm_path, conv_path]

#test_ens = (test_gru + test_lstm + test_conv) / 3
test_ens = ensemble(model_paths)
mse_ens = compute_mse(test_Y, test_ens)
acc_ens, f1_ens = compute_acc(test_Y, test_ens, thres, Cgt)
res_string = 'mse: %.4f, acc: %.4f, f1: %.4f' % (mse_ens, acc_ens, f1_ens)
with open(savedir + 'res.txt', 'w') as f:
    f.write(res_string)
    print(res_string)
# Out:
# model: models_6/GRU_0.0775.h5
# model: models_6/LSTM_0.0710.h5
# model: models_6/CONV_0.0736.h5
# mse: 0.0673, acc: 0.8312, f1: 0.8790

# %% [markdown]
# ** Show difference **

# %%
diff = pd.DataFrame([])
diff['tweet'] = pd.Series(corpus[-test_len:])
diff['snippet'] = test_set['snippet']
diff['ground truth'] = pd.Series(test_Y)
diff['prediction'] = pd.Series(test_ens)
diff['Correct?'] = pd.Series(['x' if d else 'o' for d in np.abs(np.sign(test_Y) - np.sign(test_ens))])

# %%
pd.set_option('display.max_rows', 1000)
diff
# Out:
#                                                  tweet  \
# 0    ooks pretty bullish for now. from a short term...
# 1    looks really interesting on drop, grabbed some...
# 2                          covered some shorts for pts
# 3                       Watching W triple top forming.
# 4    Whole Foods shareholders vote down activist in...
# 5    has returned to my short watchlist. Still too ...
# 6                                 Today I bought more
# 7               Short Setups Looking Nice Really Nice
# 8                     Tesla is recalling Model X cars
# 9    Thank you Google Alphabet and Facebook stocks!...
# 10                                         Short calls
# 11
# 12   Dow worst performers Chevron and Nike Best per...
# 13   borrow still which means very tight on the ava...
# 14                             cpa Guys get into and .
# 15         working on Cuba deals ahead of Obama visit
# 16           . Stockwhisperer First quarter is amazing
# 17                        Sector Stocks Leading Today
# 18     Akamai Will A Onetime Zombie Stock Rise Again?
# 19            Stocks I'm watching and buy targets , ,
# 20   MarketWatch RT wmwitkowski Guess who sold off ...
# 21   The Top brands for #millennials is #, and is w...
# 22                           looking tasty and #Twerky
# 23   Markets Back in Black for #Oil #OptionStrategies
# 24                                    Nice day rally!
# 25                          Highest call to put ratio
# 26   beats the Estimize EPS Consensus by c and the ...
# 27                    slight green May be runner later
# 28   is opening up its #XboxLive online service to ...
# 29                here we gooo Our target keep pushing
# 30   on the fence with this one. Do I have time to ...
# 31             stocks at support w high trade quality
# 32                                      In Play Longs
# 33   Supermarket Stocks Rally as Tesco Plans to Axe...
# 34                    Oil To Break Out Adding Chevron
# 35   trading of the ITM weekly calls early, vs OI o...
# 36                                    long Autocharts
# 37   on cusp of a major bollinger breakout on daily...
# 38   Liberty Global. Cable TV broadband. Mid single...
# 39                                   long this morning
# 40           I dumped and maybe buy back another time.
# 41                     Top #NetPayoutYields for March
# 42              Companies like just have cash to burn.
# 43   Commented on ParkerVision Is An Aggressive Buy...
# 44   Bullshit! All #AppleStores are EMPTY in #China...
# 45                                   AH Bottom Losses
# 46           downgrades #stocks #investing #tradeideas
# 47                     Top #NetPayoutYields for March
# 48   moves up a little more today off of cup and ha...
# 49                                       ripping early
# 50   patents turn signal detector for autonomous ca...
# 51    add in and many others. It's a theme that won...
# 52          I see a percent upside in shares from here
# 53   being sued by FTC nobody will buy them with th...
# 54    #MainStay LargeCap Growth fundholders get lif...
# 55   Intel Mulls Sale of Billion Venture Capital Po...
# 56    outperforms after CNBC column highlights Goog...
# 57   Buy these stocks while there's blood in the st...
# 58   have lost since Nov sources cited talks for a ...
# 59    on why #Facebook and other high flyers have b...
# 60   Rally Friday! #newweekhighs big and small and ...
# 61    Rant inst. ownership of actually isn't egregi...
# 62         Adobe Receives New Rating from Top Analyst
# 63   As Alcoa Kicks Off March Quarter Earnings, We ...
# 64   Yahoo's getting lots of attention, but Verizon...
# 65                            ⃣⃣Biggest Market Losers
# 66                     and still weak with and gaining
# 67   getting rid of its generic biz wouldn't have a...
# 68                                     Today's losers
# 69         Just sold Apr calls on for fees #investing
# 70   Also picked up target and target . has great u...
# 71   Regeneron Pharma Intellia Thera announce licen...
# 72   Don't like the new Starbucks reward program? N...
# 73                                    long Autocharts
# 74   Looking for sales curious about drop among a f...
# 75   Forget drone delivery. just signed a deal to l...
# 76   sold K Model 's in hours, now they just have t...
# 77                     Top #NetPayoutYields for March
# 78   Electronic Arts attracts more investors even a...
# 79                            ⃣⃣Biggest Market Losers
# 80                                   AH Bottom Losses
# 81                        watching for bounce tomorrow
# 82   It's a great step for #China to let in. Hope C...
# 83                             Taking some profits on
# 84         Breaking week highs timing looks great now
# 85                                          Timberrrr
# 86   NEW Apple hires former Amazon executive George...
# 87   . #ux has been slipping. They need to find bal...
# 88   Markets Back in Black for #Oil #OptionStrategies
# 89               U.S. airlines battle for Cuba routes
# 90   JetBlue Short Squeeze Ready To Upside w Crossi...
# 91      Juniper tumbles on Q warning Cisco also lower
# 92                          Highest call to put ratio
# 93                                      In Play Longs
# 94                        more positive comments from
# 95                    Drugs and Biotech Getting Perky
# 96   Israel wants to tax and more and CEO says taxe...
# 97    #Tesco eyes more disposals in bid to appease ...
# 98                                    long Autocharts
# 99   Followed the levels I shared with you on calls...
# 100                                      Top holdings
# 101  Facebook, near a buy point last week, faces a ...
# 102                                    DJI overbought
# 103   There was news this morning that offers will ...
# 104  Schizo stocks start strong finish weak See the...
# 105  Services like and #Hulu are growing much faste...
# 106  Goldman Sachs reiterates conviction buy on App...
# 107               U.S. consumers keep cautious stance
# 108     is taking the shine off and . As for no words.
# 109                  Locked in some puts for nice gain
# 110                       more positive comments from
# 111      not all time low , been lower to be exact in
# 112   is starting to show some relative strength an...
# 113         Baird Upgrades Tesla Motors to Outperform
# 114              U.S. airlines battle for Cuba routes
# 115                       Sector Stocks Leading Today
# 116      iPhone may not be as secure as Apple thought
# 117                                   Nice day rally!
# 118  Long at with stop loss below of buying point. ...
# 119   outperforms after CNBC column highlights Goog...
# 120      Insiders Are Selling Facebook and Ford Motor
# 121  up to after market! My members were in! Can't ...
# 122  Watching Higher, lower. and maybe fade the met...
# 123  Report Apple signs up for Google's cloud, uses...
# 124             Short Setups Looking Nice Really Nice
# 125  Notable gainers among liquid option names this...
# 126  Followed the levels I shared with you on calls...
# 127            addding tsla ss , added small vrx long
# 128  Thank you Google Alphabet and Facebook stocks!...
# 129  What a move from in Feb Headed to all time hig...
# 130           Stocks I'm watching and buy targets , ,
# 131  So people thk is a failure 'cos it has jst of ...
# 132                             Unusual Call Activity
# 133           loading and puts. think were toppy IMHO.
# 134  move off the bottom but still in bear market #...
# 135  needs to put together a master class on how to...
# 136  Indices are rallying today, but it seems like ...
# 137  Rally Friday! #newweekhighs big and small and ...
# 138   All you do is buy oil at the NYMEX close and ...
# 139  Instagram, WhatsApp And Oculus Rift Keep Faceb...
# 140        looking goo for s break out. It must hold s
# 141  new HOD with conviction keeping on watch for R...
# 142  Infection worries prompt regulatory reviews of...
# 143  Back to Back intraday reversals look out below...
# 144             Costco A Premier Retail Dividend Play
# 145  GG #PC shipments slid to lowest quarterly tota...
# 146  Good Morning! Here's some of the most trending...
# 147                                   Nice day rally!
# 148  Why Starbucks Corporation Is Pushing Channel D...
# 149  rejected that to the penny. Weak open and it g...
# 150                       Sector Stocks Leading Today
# 151  should purchase ? down , mktcap. at x its size...
# 152     Google Seeing Competition In Gigabit Internet
# 153                             Unusual Call Activity
# 154  TOP STOCK PICKS FOR TUESDAY #wallsteet #stockm...
# 155   #markets have enjoyed shorting Anglo these la...
# 156                                      Top holdings
# 157  ALERT New RSI signal created on Buy at Time St...
# 158  MarketWatch RT wmwitkowski Guess who sold off ...
# 159            stocks at support w high trade quality
# 160          downgrades #stocks #investing #tradeideas
# 161  NetApp downgraded by Macquarie to underperform...
# 162  GG #PC shipments slid to lowest quarterly tota...
# 163  signs up with Google cloud, to spend less with...
# 164  over million new Internet users are being adde...
# 165   Jason pass for me nt done good with that name...
# 166                             if breaks we see then
# 167  Unusual call buying x average volume, x, x, x,...
# 168   cook and must lobby against Judge Garland or ...
# 169         breaking out here PT in the weeks coming.
# 170  Nobody is recommending the sale of this stock....
# 171      Pivotal upgrades Alphabet ahead of Q results
# 172  reported earnings of , consensus was , Earning...
# 173        BMW entering into ride share market with i
# 174  Rally Friday! #newweekhighs big and small and ...
# 175                         Can roll over yet? Thanks.
# 176                       Sector Stocks Leading Today
# 177  Isolationism? Another Sell Rating, Sell Rating...
# 178  Stocks Higher In Afternoon Trade Intel Nears B...
# 179                    not dipping testing the day ma
# 180   daily sales slowing again, pretty timely coin...
# 181                       Sector Stocks Leading Today
# 182  Activision Blizzard Media Networks Announces R...
# 183                                   Nice day rally!
# 184  Will Amazon's massive logistics capex result i...
# 185  Schizo stocks start strong finish weak See the...
# 186  Covered Call Alerts for from InvestorsObserver...
# 187   Marriott in #Cuba tremendous opportunity awaits
# 188          downgrades #stocks #investing #tradeideas
# 189                           ⃣⃣Biggest Market Losers
# 190                                   Nice day rally!
# 191                         Highest call to put ratio
# 192     is taking the shine off and . As for no words.
# 193  chart Qualcomm Short Retracement, Trendline an...
# 194  Long at with stop loss below of buying point. ...
# 195  a new long IF is broken. Targets are , . Bears...
# 196  Analysts impressed with progress at Tesla's fl...
# 197                                              dump!
# 198                         Highest call to put ratio
# 199                                    Today's losers
# 200                    I sold and nice profit. Whew!!!
# 201  China February Retail Sales E Commerce Remains...
# 202          downgrades #stocks #investing #tradeideas
# 203  Watching Higher, lower. and maybe fade the met...
# 204             Daily Mail Considering Bid for Assets
# 205  Almost an outside day down for on big volume. ...
# 206  Indices are rallying today, but it seems like ...
# 207                                   Nice day rally!
# 208  recalling pretty much every single model X got...
# 209  Watching Higher, lower. and maybe fade the met...
# 210  Tesla Motors Inc Workers Report Low Salaries B...
# 211                                    recall model X
# 212  borrow still which means very tight on the ava...
# 213   Tesco PLC Tesco Announces Sale of Partial Sta...
# 214  down in after hour market. anyone care to expl...
# 215                                 red dragging down
# 216  China February Retail Sales E Commerce Remains...
# 217         Reasons for caution about Chinese stocks.
# 218        working on Cuba deals ahead of Obama visit
# 219  a new long IF is broken. Targets are , . Bears...
# 220   B U L L I S H B U Y A L E R T Yahoo Finance! ...
# 221     cuts outlook down . Could see fall in sympathy
# 222         recalls Model X cars. Stock dropping hard
# 223  move off the bottom but still in bear market #...
# 224   Chart Elliott Wave Chart Update Best case zig...
# 225  How does the largest cap company in the histor...
# 226          downgrades #stocks #investing #tradeideas
# 227         breaking out here PT in the weeks coming.
# 228  Schizo stocks start strong finish weak See the...
# 229   If anyone is selling shorting b c you believe...
# 230  Report Apple signs up for Google's cloud, uses...
# 231   Recall will not impact financial results Exce...
# 232  weakness continues again. area resistance afte...
# 233                       Sector Stocks Leading Today
# 234          . Stockwhisperer First quarter is amazing
# 235            stocks at support w high trade quality
# 236  this must be tiniest recall ever! Musk doing t...
# 237  Milligan Barclays on MA urgency Don't know how...
# 238  Guess the late traders will be stocking up on ...
# 239   B U L L I S H B U Y A L E R T Yahoo Finance! ...
# 240   beaten down Internet companies that may be ri...
# 241        #Facebook Imperial ambitions The Economist
# 242                         Highest call to put ratio
# 243   You highlight the REAL risk to the spec pharm...
# 244  Google, IBM, ARM And AMD Begin The Assault On ...
# 245  Report Apple signs up for Google's cloud, uses...
# 246  Tesla's stock has upside from here, says one a...
# 247                                   Nice day rally!
# 248                                         Nice start
# 249  Closed Buy Lots for pips, total for today pips...
# 250  Isolationism? Another Sell Rating, Sell Rating...
# 251                                              short
# 252   maybe or . Bad governance, not confident in c...
# 253          downgrades #stocks #investing #tradeideas
# 254  TV Remote Control Maker Surges On Deal With Co...
# 255  We are now witnessing Elon Musk’s slow motion ...
# 256               Apple's iPhone SE The Sold Out Flop
# 257            stocks at support w high trade quality
# 258  closed day swing trade Fri. for gain, short te...
# 259                                  Long on b o rumor
# 260                Holding on this with no more buys.
# 261  Commented on Apple In Need Of Innovation Sell ...
# 262                               Today I bought more
# 263                                  AH Bottom Losses
# 264             Short Setups Looking Nice Really Nice
# 265   well, technically recessions follow consecuti...
# 266  is a short below into the upper BB and is over...
# 267             Short Setups Looking Nice Really Nice
# 268  Goldman Sachs reiterates conviction buy on App...
# 269                 Tesla Motors recalls Model X SUVs
# 270   Rant inst. ownership of actually isn't egregi...
# 271  As Alcoa Kicks Off March Quarter Earnings, We ...
# 272          downgrades #stocks #investing #tradeideas
# 273  Stocks Higher In Afternoon Trade Intel Nears B...
# 274  Israel wants to tax and more and CEO says taxe...
# 275  Watching Higher, lower. and maybe fade the met...
# 276  should purchase ? down , mktcap. at x its size...
# 277  Sudden optimism about iPhone sales i.e., not a...
# 278  Google, IBM, ARM And AMD Begin The Assault On ...
# 279  great vol flow trade here Love this company lo...
# 280                               Today I bought more
# 281      Insiders Are Selling Facebook and Ford Motor
# 282  Long at with stop loss below of buying point. ...
# 283  iPhone shipments on track to exceed forecasts ...
# 284      Insiders Are Selling Facebook and Ford Motor
# 285                                     In Play Longs
# 286  ¥en up almost since Q and €uro up around ,much...
# 287  Watching Higher, lower. and maybe fade the met...
# 288                                    DJI overbought
# 289  The Three Top Stocks in are Ready to Lead Agai...
# 290                                     making new HOD
# 291  Most bullish stocks on Twitter during this dip...
# 292   Link is also increasing fees again, could be ...
# 293  Deutsche Bank downgrades Starbucks because of ...
# 294                                 Bought calls for .
# 295  GG #PC shipments slid to lowest quarterly tota...
# 296          hits a high of ! From Friday's Buy Call!
# 297   Best Analyst Rated Stocks in Last hrs View al...
# 298                           ⃣⃣Biggest Market Losers
# 299  conference. Don't underestimate Mark. Bounce o...
# 300   well, technically recessions follow consecuti...
# 301  Good Morning! Here's some of the most trending...
# 302  Express Scripts loses to on Thursday Among top...
# 303               Tesla dropped a hard J this morning
# 304   years after release, Windows XP is still the ...
# 305  Most bullish stocks on Twitter during this dip...
# 306  Baird said Q trends for Facebook appear increm...
# 307   I agree isn't going anywhere lor like buying ...
# 308                                     In Play Longs
# 309  Dow worst performers Chevron and Nike Best per...
# 310  TOP STOCK PICKS FOR TUESDAY #wallsteet #stockm...
# 311   what percentage of that will never be used? B...
# 312  honestly, it's been disappointing. Thoughts of...
# 313     I already have and adding and to the mix soon.
# 314          . Stockwhisperer First quarter is amazing
# 315          Totally agree At x earnings, is a steal.
# 316  Good Morning! Here's some of the most trending...
# 317                 bearish charts keep getting worse.
# 318  Marriott wins new Starwood deal by raising cas...
# 319  Looks like one of the best values #Lithium sto...
# 320                   Oil To Break Out Adding Chevron
# 321  Stocks Higher In Afternoon Trade Intel Nears B...
# 322   is becoming more and more the go to site for ...
# 323  Good Morning! Here's some of the most trending...
# 324  Stocks Higher In Afternoon Trade Intel Nears B...
# 325  a new long IF is broken. Targets are , . Bears...
# 326  back near , where it opened and rallied higher...
# 327            stocks at support w high trade quality
# 328  On #FEDDAY looking for a sharp move up in equi...
# 329  Followed the levels I shared with you on calls...
# 330          downgrades #stocks #investing #tradeideas
# 331        BMW entering into ride share market with i
# 332  A new PM high for was just reached. TSLA AM. F...
# 333  Report Apple signs up for Google's cloud, uses...
# 334                       Sector Stocks Leading Today
# 335  Morning Movers Starbucks Slips on Downgrade Ar...
# 336  Sunday watchlist entry from MON and going now ...
# 337   add in and many others. It's a theme that won...
# 338                                     In Play Longs
# 339  ok will make a play for ER. It's a gamble. Wil...
# 340  Sold some Puts this morning Closed them at the...
# 341                                      Top holdings
# 342                    CNBC A Up'd both short lololol
# 343                        TO TOMORROW!?! Show me the
# 344  goes deep into #machinelearning and #AI territ...
# 345  Morning Movers Starbucks Slips on Downgrade Ar...
# 346  Whole foods may feel price competition but wil...
# 347                                   Nice day rally!
# 348  China February Retail Sales E Commerce Remains...
# 349                             Unusual Call Activity
# 350  over million new Internet users are being adde...
# 351  on top of . Sanofi often on the wrong end of b...
# 352  Notable gainers among liquid option names this...
# 353  still have positive market bias Sharp Rally In...
# 354  yesterday we had sold short calls and that was...
# 355                                   long Autocharts
# 356  WSJ EU getting closer to charging Google over ...
# 357          downgrades #stocks #investing #tradeideas
# 358      Insiders Are Selling Facebook and Ford Motor
# 359  Covered Call Alerts for from InvestorsObserver...
# 360  Watching Higher, lower. and maybe fade the met...
# 361         Why Alphabet Inc was just upgraded to buy
# 362                               Today I bought more
# 363  On #FEDDAY looking for a sharp move up in equi...
# 364   You highlight the REAL risk to the spec pharm...
# 365  Either you're a trader or an investor. in is g...
# 366  TOP STOCK PICKS FOR TUESDAY #wallsteet #stockm...
# 367  Long at with stop loss below of buying point. ...
# 368          hits a high of ! From Friday's Buy Call!
# 369  Long at with stop loss below of buying point. ...
# 370                                    DJI overbought
# 371                   Oil To Break Out Adding Chevron
# 372                    Top #NetPayoutYields for March
# 373  Stocks Higher In Afternoon Trade Intel Nears B...
# 374  a new long IF is broken. Targets are , . Bears...
# 375  I've been picking up railroad stocks for the r...
# 376                                  AH Bottom Losses
# 377  Closed Buy Lots for pips, total for today pips...
# 378  Baird likes upgrades to outperform, lifts pric...
# 379   #Amazon patents system that uses selfies and ...
# 380     I already have and adding and to the mix soon.
# 381                                    Today's losers
# 382  now up w div since my original call, while up ...
# 383  Evercore ISI Ross Muken revised targets ICON t...
# 384  Unusual call buying x average volume, x, x, x,...
# 385                           ⃣⃣Biggest Market Losers
# 386  Notable gainers among liquid option names this...
# 387   Ciaccia with the skinny on why iPhone s is st...
# 388  Facebook is succeeding where Google should hav...
# 389  Facebook stock is now When or if the stock sho...
# 390   Going back in, but slowly TC alert example GLB
# 391                           ⃣⃣Biggest Market Losers
# 392  Good Morning! Here's some of the most trending...
# 393   You highlight the REAL risk to the spec pharm...
# 394   maybe or . Bad governance, not confident in c...
# 395      Insiders Are Selling Facebook and Ford Motor
# 396                                         Landed in
# 397   Biotech's have had wks of fund inflows for th...
# 398     Interest Heats Up for The Wall Street Journal
# 399                       Sector Stocks Leading Today
# 400  If you are laughing at logistic provider ambit...
# 401  Agree the valuation is high. No net cash, fwd ...
# 402  Watching Higher, lower. and maybe fade the met...
# 403  Trying to break daily trend line! Big move cou...
# 404                         Highest call to put ratio
# 405  The Three Top Stocks in are Ready to Lead Agai...
# 406  getting rid of its generic biz wouldn't have a...
# 407                           Breakout watch for TUES
# 408             Short Setups Looking Nice Really Nice
# 409                 Court tells states to leave alone
# 410  Looking for sales curious about drop among a f...
# 411   Biotech's have had wks of fund inflows for th...
# 412  Micron Technology Inc #NASDAQ down today and d...
# 413  just broke resistance, watching for a #redtogr...
# 414   #LongPos Break out thru DMA upper head res Sh...
# 415  lots of green on the min, watch the hourly pos...
# 416      Tesla to recall Model X SUVs over seat issue
# 417  Isolationism? Another Sell Rating, Sell Rating...
# 418  Goldman Sachs reiterates conviction buy on App...
# 419  Good Morning! Here's some of the most trending...
# 420  Nice names on watch for tomorrow long , short ...
# 421  ok will make a play for ER. It's a gamble. Wil...
# 422  Looking for sales curious about drop among a f...
# 423  over million new Internet users are being adde...
# 424  Worst #sentiment for #SP #stocks at market clo...
# 425  downgraded to neutral at Deutsche Bank. Price ...
# 426                                  Love it. #bullish
# 427  Most bullish stocks on Twitter during this dip...
# 428  revenue Mark Zuckerberg is doing an amazing jo...
# 429  peaks above HOD what will the buy out look lik...
# 430                         Highest call to put ratio
# 431       is setting up above its day moving average.
# 432                     RT no choice but to be positve
# 433   Note the monthly chart of how it recaptured s...
# 434   hype the news, sell on news, buy after news haha
# 435           Stay With Best Of Breed Has Room To Run
# 436   USIO ops are profitable. The drag is bloom la...
# 437  The Boeing Company NYSE BA Bearish Trader bets...
# 438  totally missed this one, was about to jump in ...
# 439            Downbeaten stocks may be ripe for buys
# 440  double bottom bounce or drops further to Gap f...
# 441              picked some up, like this going into
# 442                 Worst performers today best stock
# 443  Been doing some work on this evening. Very int...
# 444  trading at all time high after strong earnings...
# 445   bought it at sold at and its been nothing but...
# 446                               player onto the puts
# 447                            Ahha. Someone wants in
# 448                 RT VMarkets Are Still Acting Weak
# 449                is just humming easing overbought,
# 450   dont listen to news, don't look at other twit...
# 451               funny thing is is up AH on approval!
# 452  How Ron Johnson tried, and failed, to inject a...
# 453                  agree risky watching very closely
# 454    bot some breakout from the consolidation zone D
# 455                         new squeeze plays #stocks
# 456  Less than down and people are calling it beari...
# 457   Bet ya we see a on Weds especially if SPY dec...
# 458   #sectorbreadth Utilities enjoyed the best of ...
# 459  End Of Day Scan Stochastic Overbought www.dail...
# 460   Large cap tech is finally trying to catch up ...
# 461                                 very weak res. at
# 462  Put the chum out there at key support then nex...
# 463  gap up today? maybe ? they say the heat is com...
# 464  turning. Coming from far could go far. Stock p...
# 465  Curious to know why Is at and Is ? LNKD is gre...
# 466        moves better w oil anyways, oil back above
# 467  The gist of downgrades was apple failed to mak...
# 468  Another gain in following last week's huge cal...
# 469                     having a much better day than
# 470   industrial goods stocks insiders are bullish on
# 471                                         cover all
# 472              Good idea buy half this and half BAC?
# 473                      now . March puts now x , hod
# 474                                 gap fill coming up
# 475  BTW when there is turmoil in the MENA region s...
# 476   want to go this morning and it's about time l...
# 477      Bet the farm on hopeful for good things soon.
# 478      the parties over loaded on volatility is back
# 479  is looking weak while this market is moving hi...
# 480                                  Mil Buy order at
# 481                              top stocks on NASDAQ
# 482  m globally this week on avengers really sick ,...
# 483  Buffett's F Shows New Stakes in CVS Visa Gener...
# 484  gap up today? maybe ? they say the heat is com...
# 485   idk but seems to be getting a lot of hype. I ...
# 486   Got a nice push today following small sweeper...
# 487  Barry Port Unloaded Worth of The Ensign Group,...
# 488                                continues its rally
# 489       Hit With Lawsuit from Russian Search Engine
# 490      US #COCA COLA CO Oct Positive #NewsSentiment
# 491   the regular scrappy Q usually presents. Sales...
# 492                 Bid for Reargument Denied by Judge
# 493   daily chart of with upcoming first support in...
# 494         Is Yahoo looking to buy CNN? CBSNews Jan.
# 495  weekly stochastics finally starting to turn up...
# 496          Very nice breakout on a very nice stock.
# 497  real losers today are the MMs no Nasdaq transa...
# 498  Vertex. Monthly lower hi lower lo, Long term u...
# 499   F One thing you can't short here is food. Its...
# 500   share total value of company after crunching ...
# 501                            trying to drag with it.
# 502  Will take swing trade profits at leave core po...
# 503  bounce right now has no vol, more vol when it ...
# 504   another story stock with an unhappy ending. T...
# 505   has had a history of a lack of PR a shame for...
# 506  Indexes industry groups I track that closed Fr...
# 507        Avago, Broadcom To Combine In Billion Deal
# 508  Problem for shorts on Facebook now is every fu...
# 509  SOLD to close puts for . SOLD to close puts fo...
# 510                                        Add to here
# 511   in the end DropBox will end up selling for pe...
# 512  Book on Jobs makes news citing Steve Jobs sayi...
# 513          Southwest Is at Its Lowest Multiple Ever
# 514                        Moved Upper Bollinger Band
# 515               Loss of opportunity Loss of capital
# 516                                               out
# 517   more of a chartist myself news MM talk is orc...
# 518  End Of Day Scan Stochastic Overbought www.dail...
# 519
# 520                                           oversold
# 521  Key price to watch in off the previous double ...
# 522  Added. Cost now at . Bounce off of Put OI S pi...
# 523  PNC, Goldman Sachs Receive Dividend Hike Green...
# 524                 I am excited about all these plays
# 525  stopped out even from yesterdays entry at prob...
# 526  Monday commodity weakness a staple in right al...
# 527  had a nice breakout of the recent consolidatio...
# 528   Basing nice. A close over is bullish watch fo...
# 529  Headline should read Saudi's are in capable of...
# 530  this pull back of is similar to last and bulli...
# 531  RT In a mostly red tape this morning, biggest ...
# 532  Crude Oil Bears Take a Clear Near Term Advantage
# 533                           Would short on any rally
# 534  Micron Shares Pounded On Fears Of Loss Of Busi...
# 535     Sell Short Position on CNP, Closed for Profit
# 536  they're usually cheap for a reason RT my dog o...
# 537  MY short worked. Thank you for the hint. puts up
# 538   period RSI is down at , just read Connors boo...
# 539   broke amazing!!! Not really, and not the st t...
# 540  Equity indexes working on a positive engulfing...
# 541  slid to a four year low after #OPEC kept its o...
# 542                                           sideways
# 543  Out for now. Clearing some cash. Will look for...
# 544   P E with negative PL on hardware, P E profita...
# 545  sold my calls for from cents averaged aapl is ...
# 546  at resistance right here sold my shares will b...
# 547  I'm no professional ANAL yst but I DO put my w...
# 548   Roark I like this Ascending Triangle on the m...
# 549                                       out of gain
# 550  time to accumulate for a long position with fa...
# 551  Heavy volume alert. split in defensive and cyc...
# 552  Found some good bull setups this week Let's se...
# 553  Steinerâ€™s Spas Sail With the Wealthy, Defyin...
# 554           Nasdaq Sets Up for Breakout Part II via
# 555                                     Double bottom
# 556  trade continuing very nicely from yesterday, a...
# 557  havent seen vol like this since the runup. let...
# 558  and pair trade is one of my favorite trade, co...
# 559  hanging tough in down market due to analyst up...
# 560  Coal stocks are poking their head up. Here's w...
# 561                    Still holding my for next year.
# 562  IMO, Fed stimulus of any kind cud not be defen...
# 563  AP Caterpillar posts percent jump in Q profit ...
# 564  someone may have pointed this out earlier, thi...
# 565
# 566  What's more exciting, this market or watching ...
# 567  . Fundamentally nothing has changed and this c...
# 568              NEW POST China Stares Into the Abyss
# 569  Smartphone Wars Wound Samsung as Nokia Rallies...
# 570   How much are you short? It is not a High P.E....
# 571  I got bored, and took my proprietary profit ex...
# 572  has gained an average of a week for the last n...
# 573  JAPAN EARNINGS Of the of Topix companies that ...
# 574   dont listen to news, don't look at other twit...
# 575  worst idea of year? Short a reasonably priced ...
# 576  RT the correleation between the dollar index a...
# 577                     Bull Of The Day Insperity Inc
# 578  StockMasters European Debt once again Keeps St...
# 579   F. Nice little cup and handle shaping up on t...
# 580                    in deal with to bail out Greece
# 581  Sprint CFO Sees Profitability From Lightsquare...
# 582          Apple AAPL Price Target Raised to at BTIG
# 583               funny thing is is up AH on approval!
# 584                                        tapping on
# 585                             its time to sell banks
# 586            Downbeaten stocks may be ripe for buys
# 587  MT Amazing seeing everyone suddenly touting . ...
# 588    a close above and we are ready to rock and roll
# 589  Lots of metal stocks look like a run awaits. L...
# 590
# 591  Plan for rest of week Holding with stops, accu...
# 592           stop of could be used and then trail up.
# 593   Certainly getting a lot more attention recent...
# 594  seriously ER comig up and it will have to be a...
# 595                     Will re enter short on bounce
# 596   industrial goods stocks insiders are bullish on
# 597                 RT VMarkets Are Still Acting Weak
# 598         gyrating S above gap. keeping an eye on S
# 599   short float, shorts likely to take profits in...
# 600          new lows. puts , , now deep in the money
# 601                                                RT
# 602  Receives Year, Contract at New Saudi Arabian S...
# 603                              splat! poor Q orders?
# 604  With Oil Prices Down further, Oil Stocks Looki...
# 605                EUR USD Finding Support Near Level
# 606  Found some good bull setups this week Let's se...
# 607                                   huge blocks now
# 608   wants lower. up waves getting smaller on the min
# 609  great growth stk also raised dividend . clearl...
# 610                            trying to drag with it.
# 611  this could be in teens again in one trading da...
# 612  The momo leaders are taken down one by one. Lo...
# 613  End Of Day Scan Stochastic Overbought www.dail...
# 614  While we think is a winner, we are ringing the...
# 615                         new squeeze plays #stocks
# 616                      Active puts CBOE Oct Jan Jan
# 617                                     all going down
# 618  Failed breakouts failed setups. Limping on cru...
# 619   industrial goods stocks insiders are bullish on
# 620   Drop expected as London traders who took prof...
# 621         Upgraded to a buy by Alpha Street Research
# 622  is down, but weekly calls , x have volume. Wor...
# 623  expects to break even for the first time in ov...
# 624            more years will be alot to worry about
# 625  Well here you go at least you know what sector...
# 626                               so volatile! yowza P
# 627  Could the pride of social media be gettin read...
# 628  gold going parabolic wonder why? keep chasing ...
# 629  hold through all the media BS and you will be ...
# 630   I Love blood like a vampire Keep bleeding for me
# 631     Sherlock yea dude, airplanes are still flying
# 632                            Ten year yield, weekly
# 633  The best scenario going forward is this stock ...
#
#                                                snippet  ground truth  \
# 0                          ooks pretty bullish for now         0.323
# 1    [looks really interesting on drop, grabbed som...         0.579
# 2                                  covered some shorts         0.294
# 3                                  triple top forming.         0.028
# 4    Whole Foods shareholders vote down activist in...        -0.076
# 5                         Still too early for an entry        -0.387
# 6                                  Today I bought more         0.087
# 7             Short Setups Looking Nice....Really Nice        -0.464
# 8                Tesla is recalling 2,700 Model X cars        -0.291
# 9                                What a nice reversal.         0.318
# 10                                   Short $TSLA calls        -0.618
# 11              [Breakout Should be Confirmed, Upturn]         0.448
# 12                                     Best performers         0.376
# 13          very tight on the avail stock for shorting        -0.406
# 14                              get into $WFM and $MJN         0.415
# 15                               working on Cuba deals         0.419
# 16                            First quarter is amazing         0.322
# 17                         Sector Stocks Leading Today         0.454
# 18             Will A Onetime Zombie Stock Rise Again?         0.241
# 19                       I'm watching(and buy targets)         0.344
# 20              after losing about $1 billion on $VRX?        -0.643
# 21   The Top 10 brands for #millennials - $AAPL is ...         0.562
# 22                                       looking tasty         0.310
# 23                      Markets Back in Black for 2016         0.271
# 24                                     Nice day rally!         0.529
# 25                           Highest call to put ratio         0.348
# 26   beats the Estimize EPS Consensus by 6c and the...         0.366
# 27                 [slight green, May be runner later]         0.328
# 28    $MSFT is opening up its #XboxLive online service         0.225
# 29                                        here we gooo         0.268
# 30                          on the fence with this one         0.000
# 31             stocks at support w/ high trade quality         0.503
# 32                                       In Play Longs         0.273
# 33   Supermarket Stocks Rally as Tesco Plans to Axe...         0.383
# 34                  [Oil To Break Out, Adding Chevron]         0.666
# 35                      [calls, popping 5%, Stock +1%]         0.472
# 36                                                long         0.488
# 37   [on cusp of a major bollinger breakout on dail...         0.511
# 38                     Mid-single digits EBITDA growth         0.357
# 39                                   long this morning         0.476
# 40                            I dumped $PYPL and $PRLB        -0.506
# 41                                Top #NetPayoutYields         0.426
# 42                                  have cash to burn.         0.356
# 43                                      Aggressive Buy         0.306
# 44      Bullshit! All #AppleStores are EMPTY in #China        -0.329
# 45                                       Bottom Losses        -0.473
# 46                                           downgrade        -0.463
# 47                                Top #NetPayoutYields         0.426
# 48   moves up a little more today off of cup and ha...         0.306
# 49                                       ripping early         0.325
# 50   $GOOGL patents turn signal detector for autono...         0.393
# 51                                              add in         0.354
# 52   I see a 20 percent upside in $FB shares from here         0.589
# 53   [$ENDP being sued by FT, nobody will buy them ...        -0.602
# 54                LargeCap Growth fundholders get lift         0.597
# 55   Mulls Sale of $1 Billion Venture Capital Portf...         0.295
# 56                                                             0.000
# 57   Buy these 3 stocks while there's blood in the ...         0.415
# 58                    $YHOO have lost 50% since Nov 14        -0.422
# 59                       high-flyers have been falling        -0.501
# 60        [Rally Friday!, #new52weekhighs, p over 31%]         0.660
# 61                                          all higher         0.295
# 62          Adobe Receives New Rating from Top Analyst         0.141
# 63                  We See More Reasons To Be Cautious        -0.093
# 64             but Verizon is still the bidder to beat         0.404
# 65                               Biggest Market Losers        -0.438
# 66                             $FB and $IBB still weak        -0.355
# 67   [plus its Irish based,  getting rid of its gen...         0.146
# 68                                      Today's losers        -0.317
# 69                        Just sold 2 Apr-22 115 calls        -0.024
# 70                                     picked up $CALM         0.470
# 71             [advance, announce licensing agreement]         0.604
# 72   [Don't like, Neither does Wall Street, fell th...        -0.483
# 73                                                long         0.488
# 74                                           #oversold         0.406
# 75   amazon just signed a deal to lease 20 Boeing 7...         0.396
# 76                                            up $5.80         0.334
# 77                                Top #NetPayoutYields         0.426
# 78             Electronic Arts attracts more investors         0.409
# 79                               Biggest Market Losers        -0.438
# 80                                       Bottom Losses        -0.411
# 81                        watching for bounce tomorrow         0.366
# 82               a great step for #China to let $FB in         0.417
# 83                                 Taking some profits        -0.142
# 84       Breaking 52 week highs timing looks great now         0.419
# 85                                           Timberrrr        -0.562
# 86   Apple hires former Amazon executive George Sta...         0.146
# 87                                   has been slipping        -0.245
# 88                      Markets Back in Black for 2016         0.271
# 89   airlines battle for Cuba routes $AAL $LUV $SAV...         0.092
# 90   Short Squeeze Ready To Upside w Crossing Impor...         0.219
# 91                                    Cisco also lower        -0.416
# 92                           Highest call to put ratio         0.348
# 93                                       In Play Longs         0.273
# 94                     more positive comments from $MS         0.426
# 95                     Drugs and Biotech Getting Perky         0.387
# 96     [wants to ta, CEO says taxes may make co leave]        -0.265
# 97   eyes more disposals in bid to appease City bac...         0.286
# 98                                                long         0.488
# 99   [calls for nice gains, Still holding, Week mad...         0.396
# 100                                       Top holdings         0.311
# 101                         near a buy point last week         0.093
# 102                                         overbought        -0.296
# 103             offers will take place until next week         0.409
# 104                           start strong finish weak        -0.086
# 105  Services like $NFLX and #Hulu are growing much...         0.364
# 106         Goldman Sachs reiterates conviction buy on         0.622
# 107                     consumers keep cautious stance        -0.258
# 108        $FB is taking the shine off $AAPL and $GOOG        -0.130
# 109              Locked in some $FB puts for nice gain        -0.524
# 110              $NFLX more positive comments from $MS         0.085
# 111                      not all time low , been lower        -0.268
# 112            starting to show some relative strength         0.334
# 113    Baird Upgrades Tesla Motors $TSLA to Outperform         0.520
# 114  airlines battle for Cuba routes $AAL $LUV $SAV...         0.092
# 115                        Sector Stocks Leading Today         0.454
# 116                               may not be as secure        -0.308
# 117                                    Nice day rally!         0.529
# 118                               [Long, buying point]         0.230
# 119                                                            0.000
# 120                               Insiders Are Selling        -0.351
# 121                            up to $95 after market!         0.342
# 122                                   [$MDXG,  lower.]        -0.361
# 123          Report: Apple signs up for Google's cloud         0.150
# 124           Short Setups Looking Nice....Really Nice        -0.464
# 125  Notable gainers among liquid option names this...         0.513
# 126  [calls for nice gains, Still holding, Week mad...         0.396
# 127  addding tsla ss , added small vrx long $TSLA $VRX         0.394
# 128                              What a nice reversal.         0.318
# 129                           Headed to all time highs         0.407
# 130                      I'm watching(and buy targets)         0.344
# 131  orgetting the potential relative value of its ...         0.316
# 132                              Unusual Call Activity         0.332
# 133    [loading $SPY and $AAPL puts, think were toppy]        -0.537
# 134                               still in bear market        -0.421
# 135  [master class on how to conquer mobile, astoni...         0.419
# 136  [Indices are rallying today, a lot of the 'hig...        -0.193
# 137       [Rally Friday!, #new52weekhighs, p over 31%]         0.660
# 138                                                buy         0.458
# 139                         Long-Term Potential Robust         0.249
# 140  looking goo for 35.80s break out. It must hold...         0.307
# 141  new HOD with conviction keeping $570 on watch ...         0.529
# 142        Infection worries prompt regulatory reviews        -0.401
# 143  [Back to Back intraday reversals, look out bel...        -0.530
# 144                     A Premier Retail Dividend Play         0.354
# 145  [shipments slid -9.6% to lowest quarterly tota...        -0.336
# 146                                  the most trending         0.216
# 147                                    Nice day rally!         0.529
# 148                        Pushing Channel Development         0.458
# 149     Weak open and it goes r/g within first 30 mins        -0.229
# 150                        Sector Stocks Leading Today         0.454
# 151                                      $NFLX at $44B         0.215
# 152                                 Seeing Competition        -0.216
# 153                              Unusual Call Activity         0.332
# ...
# 42    -0.334828        x
# 43     0.360379        o
# 44    -0.245426        o
# 45    -0.442376        o
# 46    -0.435197        o
# 47     0.323409        o
# 48     0.257784        o
# 49     0.235355        o
# 50     0.173527        o
# 51     0.060745        o
# 52     0.397736        o
# 53    -0.161249        o
# 54     0.275676        o
# 55     0.242298        o
# 56     0.350792        x
# 57     0.366494        o
# 58    -0.226446        o
# 59    -0.390357        o
# 60     0.514119        o
# 61     0.327439        o
# 62     0.325215        o
# 63    -0.093305        o
# 64     0.225792        o
# 65    -0.443350        o
# 66    -0.257651        o
# 67     0.088722        o
# 68    -0.318166        o
# 69     0.172784        x
# 70     0.507385        o
# 71     0.362243        o
# 72     0.169167        x
# 73     0.192725        o
# 74     0.316032        o
# 75     0.356500        o
# 76     0.017500        o
# 77     0.323409        o
# 78    -0.189257        x
# 79    -0.443350        o
# 80    -0.442376        o
# 81     0.334291        o
# 82     0.301555        o
# 83    -0.198224        o
# 84     0.398919        o
# 85     0.192725        x
# 86     0.282360        o
# 87    -0.168615        o
# 88     0.236417        o
# 89     0.124536        o
# 90     0.374249        o
# 91    -0.541977        o
# 92     0.290942        o
# 93     0.183578        o
# 94     0.423578        o
# 95     0.300012        o
# 96     0.118110        x
# 97     0.056620        o
# 98     0.192725        o
# 99     0.350806        o
# 100    0.330274        o
# 101    0.174791        o
# 102   -0.265898        o
# 103    0.215391        o
# 104   -0.144572        o
# 105    0.414475        o
# 106    0.302247        o
# 107   -0.301483        o
# 108    0.155035        x
# 109   -0.256332        o
# 110    0.423578        o
# 111   -0.233980        o
# 112    0.332777        o
# 113    0.428954        o
# 114    0.124536        o
# 115    0.329926        o
# 116    0.151794        x
# 117    0.497547        o
# 118    0.116346        o
# 119    0.350792        x
# 120   -0.424280        o
# 121    0.134417        o
# 122   -0.190652        o
# 123    0.069213        o
# 124   -0.467600        o
# 125    0.436511        o
# 126    0.350806        o
# 127    0.086624        o
# 128    0.187781        o
# 129    0.145788        o
# 130    0.329491        o
# 131    0.023537        o
# 132    0.344139        o
# 133   -0.029361        o
# 134   -0.451202        o
# 135    0.023770        o
# 136   -0.109973        o
# 137    0.514119        o
# 138    0.263007        o
# 139    0.322560        o
# 140    0.325940        o
# 141    0.270869        o
# 142    0.322812        x
# 143   -0.071112        o
# 144    0.303799        o
# 145    0.229721        x
# 146    0.305090        o
# 147    0.497547        o
# 148    0.260981        o
# 149   -0.066533        o
# 150    0.329926        o
# 151    0.098869        o
# 152   -0.256707        o
# 153    0.344139        o
# 154    0.341861        o
# 155   -0.084817        o
# 156    0.330274        o
# 157    0.427098        o
# 158   -0.232473        o
# 159    0.354301        o
# 160   -0.435197        o
# 161   -0.278267        o
# 162    0.229721        x
# 163   -0.126423        o
# 164    0.262861        o
# 165    0.152867        x
# 166    0.027196        x
# 167    0.317171        o
# 168    0.132215        x
# 169    0.144499        o
# 170    0.200355        o
# 171    0.318134        o
# 172    0.406750        o
# 173    0.152724        o
# 174    0.514119        o
# 175    0.174437        x
# 176    0.329926        o
# 177   -0.357969        o
# 178    0.312446        o
# 179    0.254238        o
# 180    0.056627        x
# 181    0.329926        o
# 182    0.280139        o
# 183    0.497547        o
# 184    0.268510        x
# 185   -0.144572        o
# 186    0.218502        o
# 187    0.451135        o
# 188   -0.435197        o
# 189   -0.443350        o
# 190    0.497547        o
# 191    0.290942        o
# 192    0.155035        x
# 193   -0.206794        o
# 194    0.116346        o
# 195   -0.072152        x
# 196    0.210282        o
# 197   -0.239025        o
# 198    0.290942        o
# 199   -0.318166        o
# 200    0.150726        x
# 201    0.326523        o
# 202   -0.435197        o
# 203   -0.190652        x
# 204    0.290860        o
# 205    0.111876        x
# 206   -0.109973        o
# 207    0.497547        o
# 208    0.012683        x
# 209   -0.190652        o
# 210   -0.065618        x
# 211   -0.285661        o
# 212   -0.329050        o
# 213    0.201495        o
# 214   -0.184419        o
# 215   -0.424878        o
# 216    0.326523        o
# 217   -0.342015        o
# 218    0.340704        o
# 219   -0.072152        x
# 220   -0.176255        o
# 221   -0.391379        o
# 222   -0.528346        o
# 223   -0.451202        o
# 224    0.366151        x
# 225    0.034288        o
# 226   -0.435197        o
# 227    0.144499        o
# 228   -0.144572        o
# 229    0.416017        o
# 230    0.069213        x
# 231   -0.202438        x
# 232   -0.038654        o
# 233    0.329926        o
# 234    0.279157        o
# 235    0.354301        o
# 236   -0.269370        x
# 237    0.283798        o
# 238    0.394512        o
# 239   -0.176255        o
# 240    0.281468        o
# 241    0.192725        o
# 242    0.290942        o
# 243   -0.285023        o
# 244    0.124533        o
# 245    0.069213        o
# 246    0.367343        o
# 247    0.497547        o
# 248    0.184549        o
# 249    0.359333        o
# 250   -0.357969        o
# 251   -0.527127        o
# 252    0.048602        x
# 253   -0.435197        o
# 254    0.290559        o
# 255    0.277026        o
# 256   -0.225364        o
# 257    0.354301        o
# 258   -0.478132        o
# 259    0.078732        o
# 260    0.358358        o
# 261   -0.014392        x
# 262    0.165196        o
# 263   -0.442376        o
# 264   -0.467600        o
# 265   -0.236704        o
# 266   -0.419583        o
# 267   -0.467600        o
# 268    0.302247        o
# 269    0.016672        x
# 270    0.327439        x
# 271   -0.093305        o
# 272   -0.435197        o
# 273    0.312446        o
# 274    0.118110        x
# 275   -0.190652        x
# 276    0.098869        x
# 277   -0.094158        x
# 278    0.124533        o
# 279    0.375692        o
# 280    0.165196        o
# 281   -0.424280        o
# 282    0.116346        o
# 283    0.476297        o
# 284   -0.424280        o
# 285    0.183578        o
# 286    0.042548        o
# 287   -0.190652        x
# 288   -0.265898        o
# 289    0.313721        o
# 290    0.308517        o
# 291    0.398151        o
# 292    0.066518        o
# 293   -0.261263        o
# 294    0.497269        o
# 295    0.229721        x
# 296    0.255378        o
# 297    0.396173        o
# 298   -0.443350        o
# 299    0.380980        o
# 300   -0.236704        o
# 301    0.305090        o
# 302    0.024703        x
# 303   -0.196978        o
# 304    0.309988        o
# 305    0.398151        o
# 306    0.247754        o
# 307    0.256431        o
# 308    0.183578        o
# 309   -0.097990        x
# 310    0.341861        o
# 311   -0.094792        x
# 312    0.133969        x
# 313    0.278729        o
# 314    0.279157        o
# 315    0.327550        o
# 316    0.305090        o
# 317   -0.630003        o
# 318    0.420460        o
# 319    0.292556        o
# 320    0.536043        o
# 321    0.312446        o
# 322    0.191350        o
# 323    0.305090        o
# 324    0.312446        o
# 325   -0.072152        x
# 326    0.093090        o
# 327    0.354301        o
# 328    0.230010        o
# 329    0.350806        o
# 330   -0.435197        o
# 331    0.152724        o
# 332    0.306575        o
# 333    0.069213        x
# 334    0.329926        o
# 335   -0.021897        o
# 336    0.552629        o
# 337    0.060745        o
# 338    0.183578        o
# 339    0.506576        o
# 340   -0.113640        o
# 341    0.330274        o
# 342   -0.335309        o
# 343    0.228576        o
# 344    0.034930        o
# 345   -0.021897        o
# 346   -0.073866        o
# 347    0.497547        o
# 348    0.326523        o
# 349    0.344139        o
# 350    0.262861        o
# 351    0.165905        x
# 352    0.436511        o
# 353    0.072521        o
# 354    0.385985        o
# 355    0.192725        o
# 356   -0.067488        o
# 357   -0.435197        o
# 358   -0.424280        o
# 359    0.218502        o
# 360   -0.190652        o
# 361    0.424557        o
# 362    0.165196        o
# 363    0.230010        o
# 364   -0.285023        o
# 365    0.026930        o
# 366    0.341861        o
# 367    0.116346        o
# 368    0.255378        o
# 369    0.116346        o
# 370   -0.265898        o
# 371    0.536043        o
# 372    0.323409        o
# 373    0.312446        o
# 374   -0.072152        x
# 375    0.313031        o
# 376   -0.442376        o
# 377    0.359333        o
# 378    0.311934        o
# 379    0.247743        o
# 380    0.278729        o
# 381   -0.318166        o
# 382    0.445641        o
# 383    0.138377        o
# 384    0.317171        o
# 385   -0.443350        o
# 386    0.436511        o
# 387    0.280183        o
# 388   -0.110488        x
# 389    0.085676        o
# 390    0.209047        o
# 391   -0.443350        o
# 392    0.305090        o
# 393   -0.285023        o
# 394    0.048602        x
# 395   -0.424280        o
# 396   -0.015485        x
# 397    0.217989        o
# 398    0.258107        o
# 399    0.329926        o
# 400   -0.079229        x
# 401    0.235087        x
# 402   -0.190652        o
# 403    0.303084        o
# 404    0.290942        o
# 405    0.313721        o
# 406    0.088722        o
# 407    0.382237        o
# 408   -0.467600        o
# 409    0.223696        o
# 410    0.316032        o
# 411    0.217989        o
# 412   -0.474278        o
# 413    0.303110        o
# 414    0.152223        o
# 415    0.046867        o
# 416   -0.087479        o
# 417   -0.357969        o
# 418    0.302247        o
# 419    0.305090        o
# 420   -0.294717        x
# 421    0.506576        o
# 422    0.316032        o
# 423    0.262861        o
# 424   -0.308940        o
# 425   -0.259303        o
# 426    0.452459        o
# 427    0.398151        o
# 428    0.223583        o
# 429    0.154853        o
# 430    0.290942        o
# 431    0.217869        o
# 432    0.249470        o
# 433    0.237817        o
# 434   -0.246481        o
# 435    0.297982        o
# 436    0.047831        x
# 437   -0.202202        o
# 438    0.117324        x
# 439    0.297927        o
# 440    0.064591        x
# 441   -0.229181        x
# 442   -0.200848        o
# 443    0.292408        o
# 444    0.172616        o
# 445   -0.237561        o
# 446   -0.223258        o
# 447    0.322877        o
# 448   -0.436236        o
# 449   -0.265898        o
# 450    0.117632        o
# 451    0.433137        o
# 452    0.011090        x
# 453    0.297803        x
# 454    0.445409        o
# 455   -0.172026        o
# 456   -0.480813        o
# 457    0.326145        x
# 458    0.314416        o
# 459   -0.416079        o
# 460    0.285839        o
# 461   -0.348534        o
# 462   -0.116629        o
# 463    0.245609        o
# 464   -0.010308        x
# 465    0.123234        o
# 466    0.106333        o
# 467    0.067392        x
# 468    0.457329        o
# 469    0.307947        x
# 470    0.432510        o
# 471    0.078799        o
# 472    0.334028        o
# 473   -0.118744        o
# 474    0.276931        o
# 475    0.234582        o
# 476    0.186359        o
# 477    0.253548        o
# 478   -0.164373        o
# 479   -0.244342        o
# 480    0.193683        o
# 481    0.260352        o
# 482    0.053545        o
# 483    0.437696        o
# 484    0.245609        o
# 485    0.094735        o
# 486    0.302136        o
# 487    0.274098        x
# 488    0.364807        o
# 489   -0.147839        o
# 490    0.386390        o
# 491    0.031844        x
# 492    0.406876        x
# 493    0.190255        o
# 494    0.230961        o
# 495    0.496881        o
# 496    0.332488        o
# 497   -0.285421        o
# 498   -0.002805        x
# 499   -0.278213        o
# 500    0.144105        o
# 501    0.232096        x
# 502    0.346822        o
# 503    0.304201        o
# 504    0.172804        x
# 505   -0.174326        o
# 506    0.415826        o
# 507    0.231437        o
# 508   -0.300498        x
# 509   -0.197135        o
# 510    0.276252        o
# 511    0.111302        x
# 512   -0.072566        x
# 513    0.265773        o
# 514    0.509927        o
# 515   -0.238657        o
# 516    0.192725        x
# 517    0.377335        o
# 518   -0.416079        o
# 519    0.192725        x
# 520    0.330665        o
# 521    0.208499        x
# 522    0.286229        o
# 523    0.377803        o
# 524    0.238884        o
# 525   -0.064480        o
# 526    0.158566        x
# 527    0.352467        o
# 528    0.313206        o
# 529    0.183176        o
# 530    0.206168        x
# 531    0.334876        o
# 532   -0.391538        o
# 533   -0.119011        o
# 534    0.079848        x
# 535   -0.299182        x
# 536   -0.018899        o
# 537   -0.214622        x
# 538    0.196798        o
# 539    0.320857        o
# 540    0.275676        o
# 541    0.212526        x
# 542    0.181856        x
# 543    0.411223        x
# 544    0.098396        o
# 545   -0.041066        o
# 546    0.222123        x
# 547    0.268829        o
# 548    0.507831        o
# 549    0.192725        x
# 550    0.263011        o
# 551    0.098910        o
# 552    0.396264        o
# 553    0.411681        o
# 554    0.463069        o
# 555    0.331134        o
# 556    0.471479        o
# 557    0.238326        x
# 558    0.228207        o
# 559    0.189937        o
# 560    0.294402        o
# 561    0.274189        o
# 562    0.333426        o
# 563    0.268891        o
# 564   -0.244428        o
# 565    0.192725        o
# 566   -0.155089        x
# 567    0.203403        o
# 568    0.035248        x
# 569    0.336220        o
# 570    0.197478        o
# 571    0.106638        x
# 572    0.356095        o
# 573    0.328284        o
# 574    0.117632        o
# 575    0.232363        o
# 576    0.386790        x
# 577    0.166012        o
# 578   -0.292169        o
# 579    0.238494        o
# 580    0.096291        o
# 581    0.433211        o
# 582    0.276559        o
# 583    0.433137        o
# 584    0.192725        o
# 585   -0.247870        o
# 586    0.297927        o
# 587    0.353920        o
# 588    0.174473        o
# 589    0.364562        o
# 590    0.192725        x
# 591    0.219129        o
# 592    0.222414        o
# 593    0.255190        o
# 594    0.313843        o
# 595   -0.255867        o
# 596    0.432510        o
# 597   -0.436236        o
# 598    0.291467        o
# 599   -0.213257        o
# 600   -0.372140        o
# 601    0.192725        o
# 602    0.220857        o
# 603   -0.066582        o
# 604   -0.399307        o
# 605    0.138892        o
# 606    0.396264        o
# 607    0.300537        x
# 608   -0.214672        o
# 609    0.334408        o
# 610    0.232096        x
# 611   -0.183036        o
# 612    0.317391        x
# 613   -0.416079        o
# 614    0.293980        o
# 615   -0.172026        o
# 616   -0.448587        o
# 617   -0.328566        o
# 618   -0.356049        o
# 619    0.432510        o
# 620    0.077321        x
# 621    0.284301        o
# 622    0.374665        o
# 623    0.051966        o
# 624    0.073097        x
# 625    0.515563        o
# 626    0.253816        x
# 627   -0.297406        o
# 628    0.344392        o
# 629    0.242187        o
# 630   -0.001601        o
# 631    0.447017        o
# 632    0.251349        o
# 633    0.232274        x
